# %%
int("1"*j)
# Out:
# 1111111111

# %%
x = np.array([1.112, 2.334, 2.556])
y=(x*10**3).astype(int)
mat=np.zeros(shape=(len(x), 3+1))
str(y[0])[0]
for idx in range(len(y)):
    for val in range(3+1):
        mat[idx, val] = int(str(y[idx])[val])
        
print(mat)
diff_mat = np.diff(mat, axis=1)
print(diff_mat)
np.count_nonzero(diff_mat==0., axis=1)
# Out:
# [[1. 1. 1. 2.]
#  [2. 3. 3. 4.]
#  [2. 5. 5. 6.]]
# [[0. 0. 1.]
#  [1. 0. 1.]
#  [3. 0. 1.]]
# array([2, 1, 1])

# %%
import numpy as np
import pandas as pd

#from models import model_selection, get_best_crit
from extreme.estimators import evt_estimators
from extreme import visualization as statsviz

import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Tables

# %%
evt_estimators(n_replications=50, params={"evi":0.125, "rho":[-0.125]}, metric="mean",
                       distribution="nhw", n_data=100, return_full=False)
# Out:
# R[write to console]: Le chargement a nécessité le package : evd
#
# /opt/homebrew/Caskroom/miniforge/base/envs/rweissman/lib/python3.10/site-packages/numpy/core/_methods.py:179: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# /Users/michaelallouche/PhD/repos/revisited_weissman/extreme/estimators.py:99: RuntimeWarning: overflow encountered in power
#   gamma = (1 - np.power(np.mean(np.power(X_in / X_kn, p)), -1)) / p
#              W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE  0.507203  0.230377  0.177891  0.257097  0.233572  0.213547  0.266926
#
#          PRBps
# RMSE  0.276046

# %%
statsviz.evt_quantile_plot(n_replications=50, params={"evi":0.125, "rho":[-0.125]}, distribution="nhw", 
                           metric="mean", n_data=100)

# %% [markdown]
# ### Burr

# %% [markdown]
# #### Gamma=0.125 | Rho = -0.125

# %%
evt_estimators(n_replications=500, params={"evi":0.125, "rho":[-0.125]}, metric="mean",
                       distribution="burr", n_data=1000, return_full=False)
# Out:
#              W        RW        CW        CH       CHp     CHps      PRBp  \
# RMSE  68.59375  0.055907  4.887455  1.450659  1.450659  0.88996  2.391783
#
#          PRBps
# RMSE  0.372514

# %%
evt_estimators(n_replications=500,params={"evi":0.125, "rho":[-0.25]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE     0.19567  0.028459  0.133414  0.045806  0.045806  0.027025  0.064658
# LOGMSE  0.114545  0.031472  0.086836  0.035373  0.035373  0.021652  0.047099
#
#            PRBps
# RMSE    0.013497
# LOGMSE  0.011559

# %%
evt_estimators(n_replications=500,params={"evi":0.125, "rho":[-0.5]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE     0.04522  0.014283  0.016572  0.003424  0.003424  0.003805  0.006152
# LOGMSE  0.034297  0.015365  0.013962  0.003445  0.003445  0.003919  0.005674
#
#            PRBps
# RMSE    0.005272
# LOGMSE  0.005778

# %%
evt_estimators(n_replications=500,params={"evi":0.125, "rho":[-1.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.010972  0.009193  0.004578  0.014192  0.014192  0.012086  0.008733
# LOGMSE  0.009607   0.00981  0.004536  0.015894  0.015894  0.013339  0.009384
#
#           PRBps
# RMSE    0.01523
# LOGMSE  0.01722

# %%
evt_estimators(n_replications=500,params={"evi":0.125, "rho":[-2.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.005023   0.00633  0.007051  0.011244  0.011244  0.010336  0.009584
# LOGMSE  0.004729  0.006664  0.007684  0.013079  0.013079  0.011886  0.010888
#
#            PRBps
# RMSE    0.010158
# LOGMSE  0.011665

# %% [markdown]
# #### Gamma=0.25

# %%
evt_estimators(n_replications=500,params={"evi":0.25, "rho":[-0.125]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    5.390816  0.292155  4.073054   2.09487   2.09487  0.928851  2.047478
# LOGMSE  0.784238  0.483409  0.821586  0.601999  0.601999  0.360441  0.568311
#
#            PRBps
# RMSE    0.789229
# LOGMSE  0.344056

# %%
evt_estimators(n_replications=500,params={"evi":0.25, "rho":[-0.25]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.031922  0.109981  0.667282  0.211859  0.211859  0.130817  0.311945
# LOGMSE  0.351888  0.138587  0.282568  0.125671  0.125671  0.083105  0.163405
#
#            PRBps
# RMSE    0.061834
# LOGMSE  0.045177

# %%
evt_estimators(n_replications=500,params={"evi":0.25, "rho":[-0.5]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.203141  0.054591  0.071461  0.013575  0.013575  0.014676  0.024789
# LOGMSE  0.117958  0.062775  0.051137  0.013697  0.013697   0.01548  0.021115
#
#            PRBps
# RMSE     0.01955
# LOGMSE  0.023359

# %%
evt_estimators(n_replications=500,params={"evi":0.25, "rho":[-1.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.049146  0.033955  0.017622    0.0515    0.0515  0.044573     0.033
# LOGMSE  0.037447  0.039093  0.017844  0.064048  0.064048  0.053575  0.037549
#
#            PRBps
# RMSE    0.056064
# LOGMSE  0.070769

# %%
evt_estimators(n_replications=500,params={"evi":0.25, "rho":[-2.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.020996  0.024617  0.026187  0.040495  0.040495  0.037013   0.03466
# LOGMSE  0.018412  0.026971  0.030808   0.05445   0.05445  0.048717  0.044305
#
#            PRBps
# RMSE    0.037135
# LOGMSE  0.049074

# %% [markdown]
# #### Gamma=0.5

# %%
evt_estimators(n_replications=500,params={"evi":0.5, "rho":[-0.125]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                 W        RW          CW         CH        CHp      CHps  \
# RMSE    86.104303  0.851497  105.438523  25.282933  25.282933  9.448603
# LOGMSE   2.055932  3.215649     2.24669   1.700511   1.700511  1.206374
#
#              PRBp     PRBps
# RMSE    32.503187  7.598663
# LOGMSE    1.73064  1.222524

# %%
evt_estimators(n_replications=500,params={"evi":0.5, "rho":[-0.25]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    7.243754  0.405627  3.386962  1.196869  1.196869  0.745211  1.707853
# LOGMSE  0.884282  0.694184  0.754941  0.420466  0.420466  0.292525  0.487787
#
#            PRBps
# RMSE    0.330104
# LOGMSE  0.170579

# %%
evt_estimators(n_replications=500,params={"evi":0.5, "rho":[-0.5]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.186913  0.206327  0.370544  0.052817  0.052817  0.058391  0.117026
# LOGMSE  0.388536  0.275586  0.184629  0.055894  0.055894  0.063138  0.083918
#
#            PRBps
# RMSE     0.06796
# LOGMSE  0.096262

# %%
evt_estimators(n_replications=500,params={"evi":0.5, "rho":[-1.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.240201  0.123441  0.070812  0.179564  0.179564  0.159529  0.124235
# LOGMSE  0.140778  0.162517   0.07212  0.261096  0.261096  0.215258  0.151566
#
#            PRBps
# RMSE    0.193273
# LOGMSE  0.291306

# %%
evt_estimators(n_replications=500,params={"evi":0.5, "rho":[-2.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.094192  0.094921  0.095289  0.132727  0.132727  0.122809   0.11721
# LOGMSE  0.071213   0.10948  0.126351  0.232319  0.232319  0.205679  0.183615
#
#            PRBps
# RMSE    0.124394
# LOGMSE  0.210359

# %% [markdown]
# #### Gamma=1.

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-0.125]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                   W        RW            CW           CH          CHp  \
# RMSE    7303.119097  5.619592  12591.979049  1562.463999  1562.463999
# LOGMSE      5.74224  16.28199      5.858645     4.339515     4.339515
#
#               CHps         PRBp       PRBps
# RMSE    1814.32278  1507.922326  284.748172
# LOGMSE    3.900691     4.695966    4.100571

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-0.25]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                  W        RW         CW         CH        CHp      CHps  \
# RMSE    524.795529  1.159201  116.85511  14.103429  14.103429  5.985838
# LOGMSE    2.534789  4.031722   2.329964   1.391086   1.391086  0.983039
#
#              PRBp     PRBps
# RMSE    22.989336  2.949763
# LOGMSE   1.483116  0.644949

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-0.5]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                 W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    14.319963  0.973821  2.775482  0.227395  0.227395  0.260243  0.694837
# LOGMSE   1.192938   1.38475  0.639746  0.231831  0.231831  0.266798  0.330601
#
#            PRBps
# RMSE    0.201369
# LOGMSE  0.396669

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-1.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.632447  0.509978  0.368362  0.777524  0.777524  0.733648  0.438081
# LOGMSE  0.522965  0.723971  0.302252  1.089615  1.089615  0.880416  0.606829
#
#            PRBps
# RMSE    0.819951
# LOGMSE  1.228035

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-2.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE     0.56197  0.439271   0.35708  0.408184  0.408184  0.380699  0.382843
# LOGMSE  0.287382  0.463613  0.521037  1.030425  1.030425  0.872022  0.774775
#
#            PRBps
# RMSE    0.384544
# LOGMSE  0.929835

# %%
statsviz.evt_quantile_plot(n_replications=500, params={"evi":1., "rho":[-0.125]}, distribution="burr", 
                           metric="mean", n_data=500)

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-0.25]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                  W        RW         CW         CH        CHp      CHps  \
# RMSE    524.795529  1.159201  116.85511  14.103429  14.103429  5.985838
# LOGMSE    2.534789  4.031722   2.329964   1.391086   1.391086  0.983039
#
#              PRBp     PRBps
# RMSE    22.989336  2.949763
# LOGMSE   1.483116  0.644949

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-0.5]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                 W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    14.319963  0.973821  2.775482  0.227395  0.227395  0.260243  0.694837
# LOGMSE   1.192938   1.38475  0.639746  0.231831  0.231831  0.266798  0.330601
#
#            PRBps
# RMSE    0.201369
# LOGMSE  0.396669

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-1.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.632447  0.509978  0.368362  0.777524  0.777524  0.733648  0.438081
# LOGMSE  0.522965  0.723971  0.302252  1.089615  1.089615  0.880416  0.606829
#
#            PRBps
# RMSE    0.819951
# LOGMSE  1.228035

# %%
evt_estimators(n_replications=500,params={"evi":1., "rho":[-2.]}, metric="mean",
                       distribution="burr", n_data=500, return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE     0.56197  0.439271   0.35708  0.408184  0.408184  0.380699  0.382843
# LOGMSE  0.287382  0.463613  0.521037  1.030425  1.030425  0.872022  0.774775
#
#            PRBps
# RMSE    0.384544
# LOGMSE  0.929835

# %% [markdown]
# ### Frechet

# %%
evt_estimators(n_replications=500,params={"evi":0.125}, distribution="frechet", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.008196  0.007091  0.004906  0.008017  0.008017  0.007633  0.006446
# LOGMSE   0.00729  0.007238  0.004957  0.008787  0.008787  0.008293  0.006864
#
#            PRBps
# RMSE    0.007726
# LOGMSE  0.008417

# %%
evt_estimators(n_replications=500,params={"evi":0.25}, distribution="frechet", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.034693  0.028431  0.019489  0.029827  0.029827  0.028587  0.024841
# LOGMSE  0.027417  0.029235  0.019672  0.035497  0.035497  0.033416  0.027793
#
#            PRBps
# RMSE    0.029574
# LOGMSE  0.034814

# %%
evt_estimators(n_replications=500,params={"evi":0.5}, distribution="frechet", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE     0.16622  0.120268  0.076291  0.107102  0.107102  0.104071  0.092828
# LOGMSE  0.103033  0.120897  0.075522  0.144582  0.144582  0.135282  0.110998
#
#            PRBps
# RMSE    0.107578
# LOGMSE  0.143452

# %%
evt_estimators(n_replications=500,params={"evi":1.}, distribution="frechet", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.066694  0.647685  0.375404  0.426465  0.426465  0.427362  0.382044
# LOGMSE  0.385803  0.520099  0.302849  0.623119  0.623119  0.565062  0.452236
#
#            PRBps
# RMSE    0.432805
# LOGMSE  0.605739

# %%
statsviz.evt_quantile_plot(n_replications=500, params={"evi":1.}, distribution="frechet", 
                           metric="mean", n_data=500)

# %% [markdown]
# ### Fisher

# %%
evt_estimators(n_replications=500,params={"evi":0.125}, distribution="fisher", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.247859  0.144123   1.33127  0.817388  0.817388  0.440565  0.766571
# LOGMSE  0.381221  0.255239  0.455553  0.325622  0.325622   0.22256  0.321865
#
#            PRBps
# RMSE    0.627594
# LOGMSE   0.31037

# %%
evt_estimators(n_replications=500,params={"evi":0.25}, distribution="fisher", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.535125  0.177636  1.081461  0.605929  0.605929  0.315928  0.599223
# LOGMSE  0.417798  0.335484  0.399844  0.261302  0.261302  0.169893  0.268112
#
#            PRBps
# RMSE    0.356172
# LOGMSE  0.195978

# %%
evt_estimators(n_replications=500,params={"evi":0.5}, distribution="fisher", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.747468  0.284711  0.695522  0.261305  0.261305  0.138394  0.291842
# LOGMSE  0.464277   0.54247  0.289432  0.139037  0.139037  0.095919  0.155547
#
#            PRBps
# RMSE    0.081517
# LOGMSE  0.064117

# %%
evt_estimators(n_replications=500,params={"evi":1.}, distribution="fisher", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    2.955225  0.491205  0.293299  0.274741  0.274741  0.249235  0.202133
# LOGMSE   0.68875  1.199224  0.259977  0.641834  0.641834  0.571213  0.401771
#
#            PRBps
# RMSE    0.351742
# LOGMSE  0.939701

# %%
evt_estimators(n_replications=100,params={"evi":1.}, distribution="fisher", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    4.476457  0.414412  0.293799  0.281827  0.281827   0.25523  0.195997
# LOGMSE  0.753235  1.165664  0.237354  0.682977  0.682977  0.593119  0.382139
#
#            PRBps
# RMSE    0.359103
# LOGMSE  0.991449

# %%
statsviz.evt_quantile_plot(n_replications=500, params={"evi":1.}, distribution="fisher", 
                           metric="mean", n_data=500)

# %% [markdown]
# ### GPD

# %%
evt_estimators(n_replications=500,params={"evi":0.125}, distribution="gpd", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.870426  0.078055  0.735482  0.359899  0.359899  0.189045   0.42476
# LOGMSE  0.318355  0.096263  0.306611  0.194321  0.194321  0.113457  0.208845
#
#            PRBps
# RMSE    0.137094
# LOGMSE  0.091994

# %%
evt_estimators(n_replications=500,params={"evi":0.25}, distribution="gpd", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.031922  0.109981  0.667282  0.211859  0.211859  0.130817  0.311945
# LOGMSE  0.351888  0.138587  0.282568  0.125671  0.125671  0.083105  0.163405
#
#            PRBps
# RMSE    0.061834
# LOGMSE  0.045177

# %%
evt_estimators(n_replications=500,params={"evi":0.5}, distribution="gpd", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.186913  0.206327  0.370544  0.052817  0.052817  0.058391  0.117026
# LOGMSE  0.388536  0.275586  0.184629  0.055894  0.055894  0.063138  0.083918
#
#            PRBps
# RMSE     0.06796
# LOGMSE  0.096262

# %%
evt_estimators(n_replications=500,params={"evi":1.}, distribution="gpd", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.632447  0.509978  0.368362  0.777524  0.777524  0.733648  0.438081
# LOGMSE  0.522965  0.723971  0.302252  1.089615  1.089615  0.880416  0.606829
#
#            PRBps
# RMSE    0.819951
# LOGMSE  1.228035

# %%
evt_estimators(n_replications=50,params={"evi":1.}, distribution="gpd", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    3.048532  0.717929  0.383283  0.579128  0.579128  0.515211  0.466917
# LOGMSE  0.551118  0.898898  0.318771  1.122652  1.122652  0.907016  0.633882
#
#            PRBps
# RMSE     0.74654
# LOGMSE  1.303175

# %%
statsviz.evt_quantile_plot(n_replications=500, params={"evi":1.}, distribution="gpd", 
                           metric="mean", n_data=500)

# %% [markdown]
# ### Inverse Gamma

# %%
evt_estimators(n_replications=500,params={"evi":0.125}, distribution="invgamma", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE      0.1018  0.022676  0.037658  0.008848  0.008848  0.008138  0.013636
# LOGMSE  0.070118  0.021228  0.029859  0.008031  0.008031   0.00742  0.011611
#
#            PRBps
# RMSE    0.009375
# LOGMSE  0.009295

# %%
evt_estimators(n_replications=500,params={"evi":0.25}, distribution="invgamma", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.194924  0.059812  0.066186   0.03493   0.03493  0.032777   0.03412
# LOGMSE  0.117493   0.05443   0.04651  0.030538  0.030538  0.028294  0.025809
#
#            PRBps
# RMSE    0.037458
# LOGMSE  0.035901

# %%
evt_estimators(n_replications=500,params={"evi":0.5}, distribution="invgamma", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.381371  0.159492  0.119949  0.131829  0.131829  0.126196  0.113764
# LOGMSE  0.193248  0.151806  0.074614  0.135255  0.135255  0.123941  0.091036
#
#            PRBps
# RMSE    0.137932
# LOGMSE  0.147971

# %%
evt_estimators(n_replications=500,params={"evi":1.}, distribution="invgamma", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    1.066694  0.647685  0.375404  0.426465  0.426465  0.427362  0.382044
# LOGMSE  0.385803  0.520099  0.302849  0.623119  0.623119  0.565062  0.452236
#
#            PRBps
# RMSE    0.432805
# LOGMSE  0.605739

# %%
statsviz.evt_quantile_plot(n_replications=500, params={"evi":1.}, distribution="invgamma", 
                           metric="mean", n_data=500)

# %% [markdown]
# ### Student

# %%
evt_estimators(n_replications=500,params={"evi":0.125}, distribution="student", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE     0.32746  0.042037  0.221188  0.139656  0.139656  0.064293  0.135307
# LOGMSE  0.162382  0.051117  0.131999  0.087895  0.087895  0.047221  0.086834
#
#            PRBps
# RMSE    0.069401
# LOGMSE  0.051756

# %%
evt_estimators(n_replications=500,params={"evi":0.25}, distribution="student", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.340252  0.075245   0.14988  0.052227  0.052227  0.030477  0.071215
# LOGMSE  0.167279  0.100151  0.093438  0.038604  0.038604  0.025214  0.049441
#
#            PRBps
# RMSE    0.017631
# LOGMSE  0.015709

# %%
evt_estimators(n_replications=500,params={"evi":0.5}, distribution="student", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.359574  0.168081  0.060713  0.098973  0.098973  0.089796  0.063986
# LOGMSE   0.18393   0.25203  0.059369  0.154638  0.154638  0.139467   0.09287
#
#            PRBps
# RMSE    0.135147
# LOGMSE  0.226825

# %%
evt_estimators(n_replications=500,params={"evi":1.}, distribution="student", metric="mean", n_data=500, 
               return_full=False)
# Out:
#                W        RW        CW        CH       CHp      CHps      PRBp  \
# RMSE    0.547953  0.429893  0.466644  0.587004  0.587004  0.554235  0.536812
# LOGMSE  0.314579  0.591135  0.710884  1.769334  1.769334  1.449815  1.200754
#
#            PRBps
# RMSE    0.575353
# LOGMSE  1.724415

# %%
statsviz.evt_quantile_plot(n_replications=500, params={"evi":1.}, distribution="student", 
                           metric="mean", n_data=500)

# %% [markdown]
# # Plots
