# %%
import numpy as np
import pandas as pd

#from models import model_selection, get_best_crit
from extreme.estimators import evt_estimators, real_estimators
from extreme import visualization as statsviz
from scipy import stats
import matplotlib.pyplot as plt
from pathlib import Path

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Simulated data

# %%
evt_estimators(n_replications=1000, params={"evi":0.125, "rho": -1.},
                distribution="burr", 
               n_data=500, n_quantile="2n")
# Out:
#            W      RW      CW      CH     CHp   PRBp    CHps   PRBps
# RMSE  0.0471  0.0095  0.0063  0.0155  0.0149  0.015  0.0135  0.0164

# %%
statsviz.evt_quantile_plot(n_replications=1000, params={"evi":0.125, "rho": -0.5}, 
                           distribution="burr", 
                            n_data=500, n_quantile="2n")

# %%
statsviz.evt_quantile_plot_paper(n_replications=1000, params={"evi":0.25, "rho": -0.5}, 
                           distribution="burr", 
                            n_data=500, n_quantile="n", plot_type='rmse', saved=True)

# %%
statsviz.evt_quantile_plot_paper(n_replications=1000, params={"evi":0.125}, 
                           distribution="fisher", 
                            n_data=500, n_quantile="2n", plot_type='rmse', saved=False)

# %%
statsviz.evt_hill_plot(n_replications=1000, params={"evi":0.25, "rho": -2.}, 
                           distribution="burr", 
                            n_data=500, n_quantile="n", saved=True)
# Out:
# R[write to console]: Le chargement a nécessité le package : evd
# 150.8895404059642

# %%
statsviz.evt_hill_plot(n_replications=1000, params={"evi":0.25, "rho": -0.5}, 
                           distribution="burr", 
                            n_data=500, n_quantile="n", saved=True)
# Out:
# 133.1211960741222

# %% [markdown]
# # Real data

# %%
# seed 42
real_estimators()
# Out:
#                 W      RW      CW      CH     CHp   PRBp    CHps   PRBps
# quantile  11.7587  8.2985  8.2031  7.1359  7.1359  7.104  7.0913  7.1084
# k             177     210     203     199     199    196     202     190

# %%
np.arange(0.6, 1.3, 0.1)
# Out:
# array([0.6, 0.7, 0.8, 0.9, 1. , 1.1, 1.2])

# %%
# seed 42
statsviz.real_quantile_plot_paper(saved=True)

# %%
statsviz.real_hill_plot(saved=True)

# %%
statsviz.real_loglog_plot(saved=True)

# %%
statsviz.real_hist_plot(saved=True)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
# confidence interval

alpha = stats.norm.ppf(0.975)
d_n = 210
kn_star = 69
sigma_2 = np.square(0.2801)
real_quantile = 7898639
estimated_quantile = 8203143.99
replications = 1000
bound = (sigma_2 * np.square(np.log(d_n)) / kn_star) * real_quantile
print("Confidence Interval = [{:.4f}, {:.4f}]".format(estimated_quantile - alpha*bound, estimated_quantile + alpha*bound))
# Out:
# Confidence Interval = [7699857.4462, 8706430.5338]

# %%
# seed 43 
"""
Leger decalage pour les estimateurs CH, CHp, PRBp CHps, PRBps avec une autre seed sur l'algo de choix de k ...
"""
real_estimators()
# Out:
#                 W      RW      CW      CH     CHp   PRBp    CHps   PRBps
# quantile  11.7587  8.2985  8.2031  6.9685  6.9685  7.119  7.0654  6.9684
# k             177     210     203     203     203    202     203     196
