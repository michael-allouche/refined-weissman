# %%
import numpy as np
import pandas as pd

from extreme.estimators import evt_estimators, real_estimators
from extreme import visualization as statsviz
from scipy import stats
import matplotlib.pyplot as plt
from pathlib import Path

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Simulated data

# %% [markdown]
# ## Table RMSE

# %%
evt_estimators(n_replications=1000, params={"evi":0.125, "rho": -1.},
                distribution="burr", 
               n_data=500, n_quantile="2n")
# Out:
#            W      RW      CW      CH     CHp   PRBp    CHps   PRBps
# RMSE  0.0471  0.0095  0.0063  0.0155  0.0149  0.015  0.0135  0.0164

# %% [markdown]
# ## Illustration of Bias/Variance/RMSE

# %%
statsviz.evt_quantile_plot(n_replications=1000, params={"evi":0.125, "rho": -0.125}, 
                           distribution="burr", 
                            n_data=500, n_quantile="2n")

# %% [markdown]
# ## Hill plot

# %%
statsviz.evt_hill_plot(n_replications=1000, params={"evi":0.125, "rho": -1.}, 
                           distribution="burr", 
                            n_data=500, n_quantile="n")

# %% [markdown]
# # Real data

# %% [markdown]
# ## Table RMSE

# %%
real_estimators()
# Out:
#                 W      RW      CW      CH     CHp   PRBp    CHps   PRBps
# quantile  11.7587  8.2985  8.2031  7.1359  7.1359  7.104  7.0913  7.1084
# k             177     210     203     199     199    196     202     190

# %% [markdown]
# ## Illustration of Bias

# %%
statsviz.real_quantile_plot()

# %% [markdown]
# ## Hill plot

# %%
statsviz.real_hill_plot()

# %% [markdown]
# ## Log-Log plot

# %%
statsviz.real_loglog_plot()

# %% [markdown]
# ## Histrogram

# %%
statsviz.real_hist_plot()
